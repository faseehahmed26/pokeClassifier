# %%
import os
import pathlib
import numpy as np


import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D

# %%
gpu_devices = tf.config.experimental.list_physical_devices("GPU")
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

print("GPU Name: ", gpu_devices)
print("Is TF built with CUDA: ", tf.test.is_built_with_cuda())
# Out:
# GPU Name:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Is TF built with CUDA:  True

# %%
# %matplotlib inline
sns.set_style("whitegrid")

# %% [markdown]
# ## Import Data

# %%
DATA_PATH = "../archive (1)/images/images/"
data_dir = pathlib.Path(DATA_PATH)

# %%
data_dir
# Out:
# WindowsPath('../archive (1)/images/images')

# %% [markdown]
# ### Number of total images.

# %%
image_count = len(list(data_dir.glob('*')))
image_count
# Out:
# 810

# %% [markdown]
# ### Number of classes.

# %%
class_names = [item.name.split('.')[0].lower() for item in data_dir.glob('*')]
len(class_names)
# Out:
# 810

# %% [markdown]
# ### Dictionary for class <=> id conversion

# %%
class2idx = {v:k for k,v in enumerate(class_names)}
idx2class = {v:k for k,v in class2idx.items()}

# %%
class2idx
# Out:
# {'abomasnow': 0,
#  'abra': 1,
#  'absol': 2,
#  'accelgor': 3,
#  'aegislash-blade': 4,
#  'aerodactyl': 5,
#  'aggron': 6,
#  'aipom': 7,
#  'alakazam': 8,
#  'alomomola': 9,
#  'altaria': 10,
#  'amaura': 11,
#  'ambipom': 12,
#  'amoonguss': 13,
#  'ampharos': 14,
#  'anorith': 15,
#  'araquanid': 16,
#  'arbok': 17,
#  'arcanine': 18,
#  'arceus': 19,
#  'archen': 20,
#  'archeops': 21,
#  'ariados': 22,
#  'armaldo': 23,
#  'aromatisse': 24,
#  'aron': 25,
#  'articuno': 26,
#  'audino': 27,
#  'aurorus': 28,
#  'avalugg': 29,
#  'axew': 30,
#  'azelf': 31,
#  'azumarill': 32,
#  'azurill': 33,
#  'bagon': 34,
#  'baltoy': 35,
#  'banette': 36,
#  'barbaracle': 37,
#  'barboach': 38,
#  'basculin-red-striped': 39,
#  'bastiodon': 40,
#  'bayleef': 41,
#  'beartic': 42,
#  'beautifly': 43,
#  'beedrill': 44,
#  'beheeyem': 45,
#  'beldum': 46,
#  'bellossom': 47,
#  'bellsprout': 48,
#  'bergmite': 49,
#  'bewear': 50,
#  'bibarel': 51,
#  'bidoof': 52,
#  'binacle': 53,
#  'bisharp': 54,
#  'blacephalon': 55,
#  'blastoise': 56,
#  'blaziken': 57,
#  'blissey': 58,
#  'blitzle': 59,
#  'boldore': 60,
#  'bonsly': 61,
#  'bouffalant': 62,
#  'bounsweet': 63,
#  'braixen': 64,
#  'braviary': 65,
#  'breloom': 66,
#  'brionne': 67,
#  'bronzong': 68,
#  'bronzor': 69,
#  'bruxish': 70,
#  'budew': 71,
#  'buizel': 72,
#  'bulbasaur': 73,
#  'buneary': 74,
#  'bunnelby': 75,
#  'burmy': 76,
#  'butterfree': 77,
#  'buzzwole': 78,
#  'cacnea': 79,
#  'cacturne': 80,
#  'camerupt': 81,
#  'carbink': 82,
#  'carnivine': 83,
#  'carracosta': 84,
#  'carvanha': 85,
#  'cascoon': 86,
#  'castform': 87,
#  'caterpie': 88,
#  'celebi': 89,
#  'celesteela': 90,
#  'chandelure': 91,
#  'chansey': 92,
#  'charizard': 93,
#  'charjabug': 94,
#  'charmander': 95,
#  'charmeleon': 96,
#  'chatot': 97,
#  'cherrim': 98,
#  'cherubi': 99,
#  'chesnaught': 100,
#  'chespin': 101,
#  'chikorita': 102,
#  'chimchar': 103,
#  'chimecho': 104,
#  'chinchou': 105,
#  'chingling': 106,
#  'cinccino': 107,
#  'clamperl': 108,
#  'clauncher': 109,
#  'clawitzer': 110,
#  'claydol': 111,
#  'clefable': 112,
#  'clefairy': 113,
#  'cleffa': 114,
#  'cloyster': 115,
#  'cobalion': 116,
#  'cofagrigus': 117,
#  'combee': 118,
#  'combusken': 119,
#  'comfey': 120,
#  'conkeldurr': 121,
#  'corphish': 122,
#  'corsola': 123,
#  'cosmoem': 124,
#  'cosmog': 125,
#  'cottonee': 126,
#  'crabominable': 127,
#  'crabrawler': 128,
#  'cradily': 129,
#  'cranidos': 130,
#  'crawdaunt': 131,
#  'cresselia': 132,
#  'croagunk': 133,
#  'crobat': 134,
#  'croconaw': 135,
#  'crustle': 136,
#  'cryogonal': 137,
#  'cubchoo': 138,
#  'cubone': 139,
#  'cutiefly': 140,
#  'cyndaquil': 141,
#  'darkrai': 142,
#  'darmanitan-standard': 143,
#  'dartrix': 144,
#  'darumaka': 145,
#  'decidueye': 146,
#  'dedenne': 147,
#  'deerling': 148,
#  'deino': 149,
#  'delcatty': 150,
#  'delibird': 151,
#  'delphox': 152,
#  'deoxys-normal': 153,
#  'dewgong': 154,
#  'dewott': 155,
#  'dewpider': 156,
#  'dhelmise': 157,
#  'dialga': 158,
#  'diancie': 159,
#  'diggersby': 160,
#  'diglett': 161,
#  'ditto': 162,
#  'dodrio': 163,
#  'doduo': 164,
#  'donphan': 165,
#  'doublade': 166,
#  'dragalge': 167,
#  'dragonair': 168,
#  'dragonite': 169,
#  'drampa': 170,
#  'drapion': 171,
#  'dratini': 172,
#  'drifblim': 173,
#  'drifloon': 174,
#  'drilbur': 175,
#  'drowzee': 176,
#  'druddigon': 177,
#  'ducklett': 178,
#  'dugtrio': 179,
#  'dunsparce': 180,
#  'duosion': 181,
#  'durant': 182,
#  'dusclops': 183,
#  'dusknoir': 184,
#  'duskull': 185,
#  'dustox': 186,
#  'dwebble': 187,
#  'eelektrik': 188,
#  'eelektross': 189,
#  'eevee': 190,
#  'ekans': 191,
#  'electabuzz': 192,
#  'electivire': 193,
#  'electrike': 194,
#  'electrode': 195,
#  'elekid': 196,
#  'elgyem': 197,
#  'emboar': 198,
#  'emolga': 199,
#  'empoleon': 200,
#  'entei': 201,
#  'escavalier': 202,
#  'espeon': 203,
#  'espurr': 204,
#  'excadrill': 205,
#  'exeggcute': 206,
#  'exeggutor': 207,
#  'exploud': 208,
#  'farfetchd': 209,
#  'fearow': 210,
#  'feebas': 211,
#  'fennekin': 212,
#  'feraligatr': 213,
#  'ferroseed': 214,
#  'ferrothorn': 215,
#  'finneon': 216,
#  'flaaffy': 217,
#  'flabebe': 218,
#  'flareon': 219,
#  'fletchinder': 220,
#  'fletchling': 221,
#  'floatzel': 222,
#  'floette': 223,
#  'florges': 224,
#  'flygon': 225,
#  'fomantis': 226,
#  'foongus': 227,
#  'forretress': 228,
#  'fraxure': 229,
#  'frillish': 230,
#  'froakie': 231,
#  'frogadier': 232,
#  'froslass': 233,
#  'furfrou': 234,
#  'furret': 235,
#  'gabite': 236,
#  'gallade': 237,
#  'galvantula': 238,
#  'garbodor': 239,
#  'garchomp': 240,
#  'gardevoir': 241,
#  'gastly': 242,
#  'gastrodon': 243,
#  'genesect': 244,
#  'gengar': 245,
#  'geodude': 246,
#  'gible': 247,
#  'gigalith': 248,
#  'girafarig': 249,
#  'giratina-altered': 250,
#  'glaceon': 251,
#  'glalie': 252,
#  'glameow': 253,
#  'gligar': 254,
#  'gliscor': 255,
#  'gloom': 256,
#  'gogoat': 257,
#  'golbat': 258,
#  'goldeen': 259,
#  'golduck': 260,
#  'golem': 261,
#  'golett': 262,
#  'golisopod': 263,
#  'golurk': 264,
#  'goodra': 265,
#  'goomy': 266,
#  'gorebyss': 267,
#  'gothita': 268,
#  'gothitelle': 269,
#  'gothorita': 270,
#  'gourgeist-average': 271,
#  'granbull': 272,
#  'graveler': 273,
#  'greninja': 274,
#  'grimer': 275,
#  'grotle': 276,
#  'groudon': 277,
#  'grovyle': 278,
#  'growlithe': 279,
#  'grubbin': 280,
#  'grumpig': 281,
#  'gulpin': 282,
#  'gumshoos': 283,
#  'gurdurr': 284,
#  'guzzlord': 285,
#  'gyarados': 286,
#  'hakamo-o': 287,
#  'happiny': 288,
#  'hariyama': 289,
#  'haunter': 290,
#  'hawlucha': 291,
#  'haxorus': 292,
#  'heatmor': 293,
#  'heatran': 294,
#  'heliolisk': 295,
#  'helioptile': 296,
#  'heracross': 297,
#  'herdier': 298,
#  'hippopotas': 299,
#  'hippowdon': 300,
#  'hitmonchan': 301,
#  'hitmonlee': 302,
#  'hitmontop': 303,
#  'ho-oh': 304,
#  'honchkrow': 305,
#  'honedge': 306,
#  'hoopa-confined': 307,
#  'hoothoot': 308,
#  'hoppip': 309,
#  'horsea': 310,
#  'houndoom': 311,
#  'houndour': 312,
#  'huntail': 313,
#  'hydreigon': 314,
#  'hypno': 315,
#  'igglybuff': 316,
#  'illumise': 317,
#  'incineroar': 318,
#  'infernape': 319,
#  'inkay': 320,
#  'ivysaur': 321,
#  'jangmo-o': 322,
#  'jellicent': 323,
#  'jigglypuff': 324,
#  'jirachi': 325,
#  'jolteon': 326,
#  'joltik': 327,
#  'jumpluff': 328,
#  'jynx': 329,
#  'kabuto': 330,
#  'kabutops': 331,
#  'kadabra': 332,
#  'kakuna': 333,
#  'kangaskhan': 334,
#  'karrablast': 335,
#  'kartana': 336,
#  'kecleon': 337,
#  'keldeo-ordinary': 338,
#  'kingdra': 339,
#  'kingler': 340,
#  'kirlia': 341,
#  'klang': 342,
#  'klefki': 343,
#  'klink': 344,
#  'klinklang': 345,
#  'koffing': 346,
#  'komala': 347,
#  'kommo-o': 348,
#  'krabby': 349,
#  'kricketot': 350,
#  'kricketune': 351,
#  'krokorok': 352,
#  'krookodile': 353,
#  'kyogre': 354,
#  'kyurem': 355,
#  'lairon': 356,
#  'lampent': 357,
#  'landorus-incarnate': 358,
#  'lanturn': 359,
#  'lapras': 360,
#  'larvesta': 361,
#  'larvitar': 362,
#  'latias': 363,
#  'latios': 364,
#  'leafeon': 365,
#  'leavanny': 366,
#  'ledian': 367,
#  'ledyba': 368,
#  'lickilicky': 369,
#  'lickitung': 370,
#  'liepard': 371,
#  'lileep': 372,
#  'lilligant': 373,
#  'lillipup': 374,
#  'linoone': 375,
#  'litleo': 376,
#  'litten': 377,
#  'litwick': 378,
#  'lombre': 379,
#  'lopunny': 380,
#  'lotad': 381,
#  'loudred': 382,
#  'lucario': 383,
#  'ludicolo': 384,
#  'lugia': 385,
#  'lumineon': 386,
#  'lunala': 387,
#  'lunatone': 388,
#  'lurantis': 389,
#  'luvdisc': 390,
#  'luxio': 391,
#  'luxray': 392,
#  'lycanroc-midday': 393,
#  'machamp': 394,
#  'machoke': 395,
#  'machop': 396,
#  'magby': 397,
#  'magcargo': 398,
#  'magearna': 399,
#  'magikarp': 400,
#  'magmar': 401,
#  'magmortar': 402,
#  'magnemite': 403,
#  'magneton': 404,
#  'magnezone': 405,
#  'makuhita': 406,
#  'malamar': 407,
#  'mamoswine': 408,
#  'manaphy': 409,
#  'mandibuzz': 410,
#  'manectric': 411,
#  'mankey': 412,
#  'mantine': 413,
#  'mantyke': 414,
#  'maractus': 415,
#  'mareanie': 416,
#  'mareep': 417,
#  'marill': 418,
#  'marowak': 419,
#  'marshadow': 420,
#  'marshtomp': 421,
#  'masquerain': 422,
#  'mawile': 423,
#  'medicham': 424,
#  'meditite': 425,
#  'meganium': 426,
#  'melmetal': 427,
#  'meloetta-aria': 428,
#  'meltan': 429,
#  'meowstic-male': 430,
#  'meowth': 431,
#  'mesprit': 432,
#  'metagross': 433,
#  'metang': 434,
#  'metapod': 435,
#  'mew': 436,
#  'mewtwo': 437,
#  'mienfoo': 438,
#  'mienshao': 439,
#  'mightyena': 440,
#  'milotic': 441,
#  'miltank': 442,
#  'mime-jr': 443,
#  'mimikyu': 444,
#  'minccino': 445,
#  'minior-meteor': 446,
#  'minun': 447,
#  'misdreavus': 448,
#  'mismagius': 449,
#  'model_js': 450,
#  'moltres': 451,
#  'monferno': 452,
#  'morelull': 453,
#  'mothim': 454,
#  'mr-mime': 455,
#  'mudbray': 456,
#  'mudkip': 457,
#  'mudsdale': 458,
#  'muk': 459,
#  'munchlax': 460,
#  'munna': 461,
#  'murkrow': 462,
#  'musharna': 463,
#  'naganadel': 464,
#  'natu': 465,
#  'necrozma': 466,
#  'nidoking': 467,
#  'nidoqueen': 468,
#  'nidoran-f': 469,
#  'nidoran-m': 470,
#  'nidorina': 471,
#  'nidorino': 472,
#  'nihilego': 473,
#  'nincada': 474,
#  'ninetales': 475,
#  'ninjask': 476,
#  'noctowl': 477,
#  'noibat': 478,
#  'noivern': 479,
#  'nosepass': 480,
#  'numel': 481,
#  'nuzleaf': 482,
#  'octillery': 483,
#  'oddish': 484,
#  'omanyte': 485,
#  'omastar': 486,
#  'onix': 487,
#  'oranguru': 488,
#  'oricorio-baile': 489,
#  'oshawott': 490,
#  'pachirisu': 491,
#  'palkia': 492,
#  'palossand': 493,
#  'palpitoad': 494,
#  'pancham': 495,
#  'pangoro': 496,
#  'panpour': 497,
#  'pansage': 498,
#  'pansear': 499,
#  'paras': 500,
#  'parasect': 501,
#  'passimian': 502,
#  'patrat': 503,
#  'pawniard': 504,
#  'pelipper': 505,
#  'persian': 506,
#  'petilil': 507,
#  'phanpy': 508,
#  'phantump': 509,
#  'pheromosa': 510,
#  'phione': 511,
#  'pichu': 512,
#  'pidgeot': 513,
#  'pidgeotto': 514,
#  'pidgey': 515,
#  'pidove': 516,
#  'pignite': 517,
#  'pikachu': 518,
#  'pikipek': 519,
#  'piloswine': 520,
#  'pineco': 521,
#  'pinsir': 522,
#  'piplup': 523,
#  'plusle': 524,
#  'poipole': 525,
#  'politoed': 526,
#  'poliwag': 527,
#  'poliwhirl': 528,
#  'poliwrath': 529,
#  'ponyta': 530,
#  'poochyena': 531,
#  'popplio': 532,
#  'porygon-z': 533,
#  'porygon': 534,
#  'porygon2': 535,
#  'primarina': 536,
#  'primeape': 537,
#  'prinplup': 538,
#  'probopass': 539,
#  'psyduck': 540,
#  'pumpkaboo-average': 541,
#  'pupitar': 542,
#  'purrloin': 543,
#  'purugly': 544,
#  'pyroar': 545,
#  'pyukumuku': 546,
#  'quagsire': 547,
#  'quilava': 548,
#  'quilladin': 549,
#  'qwilfish': 550,
#  'raichu': 551,
#  'raikou': 552,
#  'ralts': 553,
#  'rampardos': 554,
#  'rapidash': 555,
#  'raticate': 556,
#  'rattata': 557,
#  'rayquaza': 558,
#  'regice': 559,
#  'regigigas': 560,
#  'regirock': 561,
#  'registeel': 562,
#  'relicanth': 563,
#  'remoraid': 564,
#  'reshiram': 565,
#  'reuniclus': 566,
#  'rhydon': 567,
#  'rhyhorn': 568,
#  'rhyperior': 569,
#  'ribombee': 570,
#  'riolu': 571,
#  'rockruff': 572,
#  'roggenrola': 573,
#  'roselia': 574,
#  'roserade': 575,
#  'rotom': 576,
#  'rowlet': 577,
#  'rufflet': 578,
#  'sableye': 579,
#  'salamence': 580,
#  'salandit': 581,
#  'salazzle': 582,
#  'samurott': 583,
#  'sandile': 584,
#  'sandshrew': 585,
#  'sandslash': 586,
#  'sandygast': 587,
#  'sawk': 588,
#  'sawsbuck': 589,
#  'scatterbug': 590,
#  'sceptile': 591,
#  'scizor': 592,
#  'scolipede': 593,
#  'scrafty': 594,
#  'scraggy': 595,
#  'scyther': 596,
#  'seadra': 597,
#  'seaking': 598,
#  'sealeo': 599,
#  'seedot': 600,
#  'seel': 601,
#  'seismitoad': 602,
#  'sentret': 603,
#  'serperior': 604,
#  'servine': 605,
#  'seviper': 606,
#  'sewaddle': 607,
#  'sharpedo': 608,
#  'shaymin-land': 609,
#  'shedinja': 610,
#  'shelgon': 611,
#  'shellder': 612,
#  'shellos': 613,
#  'shelmet': 614,
#  'shieldon': 615,
#  'shiftry': 616,
#  'shiinotic': 617,
#  'shinx': 618,
#  'shroomish': 619,
#  'shuckle': 620,
#  'shuppet': 621,
#  'sigilyph': 622,
#  'silcoon': 623,
#  'silvally': 624,
#  'simipour': 625,
#  'simisage': 626,
#  'simisear': 627,
#  'skarmory': 628,
#  'skiddo': 629,
#  'skiploom': 630,
#  'skitty': 631,
#  'skorupi': 632,
#  'skrelp': 633,
#  'skuntank': 634,
#  'slaking': 635,
#  'slakoth': 636,
#  'sliggoo': 637,
#  'slowbro': 638,
#  'slowking': 639,
#  'slowpoke': 640,
#  'slugma': 641,
#  'slurpuff': 642,
#  'smeargle': 643,
#  'smoochum': 644,
#  'sneasel': 645,
#  'snivy': 646,
#  'snorlax': 647,
#  'snorunt': 648,
#  'snover': 649,
#  'snubbull': 650,
#  'solgaleo': 651,
#  'solosis': 652,
#  'solrock': 653,
#  'spearow': 654,
#  'spewpa': 655,
#  'spheal': 656,
#  'spinarak': 657,
#  'spinda': 658,
#  'spiritomb': 659,
#  'spoink': 660,
#  'spritzee': 661,
#  'squirtle': 662,
#  'stakataka': 663,
#  'stantler': 664,
#  'staraptor': 665,
#  'staravia': 666,
#  'starly': 667,
#  'starmie': 668,
#  'staryu': 669,
#  'steelix': 670,
#  'steenee': 671,
#  'stoutland': 672,
#  'stufful': 673,
#  'stunfisk': 674,
#  'stunky': 675,
#  'sudowoodo': 676,
#  'suicune': 677,
#  'sunflora': 678,
#  'sunkern': 679,
#  'surskit': 680,
#  'swablu': 681,
#  'swadloon': 682,
#  'swalot': 683,
#  'swampert': 684,
#  'swanna': 685,
#  'swellow': 686,
#  'swinub': 687,
#  'swirlix': 688,
#  'swoobat': 689,
#  'sylveon': 690,
#  'taillow': 691,
#  'talonflame': 692,
#  'tangela': 693,
#  'tangrowth': 694,
#  'tapu-bulu': 695,
#  'tapu-fini': 696,
#  'tapu-koko': 697,
#  'tapu-lele': 698,
#  'tauros': 699,
#  'teddiursa': 700,
#  'tentacool': 701,
#  'tentacruel': 702,
#  'tepig': 703,
#  'terrakion': 704,
#  'throh': 705,
#  'thundurus-incarnate': 706,
#  'timburr': 707,
#  'tirtouga': 708,
#  'togedemaru': 709,
#  'togekiss': 710,
#  'togepi': 711,
#  'togetic': 712,
#  'torchic': 713,
#  'torkoal': 714,
#  'tornadus-incarnate': 715,
#  'torracat': 716,
#  'torterra': 717,
#  'totodile': 718,
#  'toucannon': 719,
#  'toxapex': 720,
#  'toxicroak': 721,
#  'tranquill': 722,
#  'trapinch': 723,
#  'treecko': 724,
#  'trevenant': 725,
#  'tropius': 726,
#  'trubbish': 727,
#  'trumbeak': 728,
#  'tsareena': 729,
#  'turtonator': 730,
#  'turtwig': 731,
#  'tympole': 732,
#  'tynamo': 733,
#  'type-null': 734,
#  'typhlosion': 735,
#  'tyranitar': 736,
#  'tyrantrum': 737,
#  'tyrogue': 738,
#  'tyrunt': 739,
#  'umbreon': 740,
#  'unfezant': 741,
#  'unown': 742,
#  'ursaring': 743,
#  'uxie': 744,
#  'vanillish': 745,
#  'vanillite': 746,
#  'vanilluxe': 747,
#  'vaporeon': 748,
#  'venipede': 749,
#  'venomoth': 750,
#  'venonat': 751,
#  'venusaur': 752,
#  'vespiquen': 753,
#  'vibrava': 754,
#  'victini': 755,
#  'victreebel': 756,
#  'vigoroth': 757,
#  'vikavolt': 758,
#  'vileplume': 759,
#  'virizion': 760,
#  'vivillon': 761,
#  'volbeat': 762,
#  'volcanion': 763,
#  'volcarona': 764,
#  'voltorb': 765,
#  'vullaby': 766,
#  'vulpix': 767,
#  'wailmer': 768,
#  'wailord': 769,
#  'walrein': 770,
#  'wartortle': 771,
#  'watchog': 772,
#  'weavile': 773,
#  'weedle': 774,
#  'weepinbell': 775,
#  'weezing': 776,
#  'whimsicott': 777,
#  'whirlipede': 778,
#  'whiscash': 779,
#  'whismur': 780,
#  'wigglytuff': 781,
#  'wimpod': 782,
#  'wingull': 783,
#  'wishiwashi-solo': 784,
#  'wobbuffet': 785,
#  'woobat': 786,
#  'wooper': 787,
#  'wormadam-plant': 788,
#  'wurmple': 789,
#  'wynaut': 790,
#  'xatu': 791,
#  'xerneas': 792,
#  'xurkitree': 793,
#  'yamask': 794,
#  'yanma': 795,
#  'yanmega': 796,
#  'yungoos': 797,
#  'yveltal': 798,
#  'zangoose': 799,
#  'zapdos': 800,
#  'zebstrika': 801,
#  'zekrom': 802,
#  'zeraora': 803,
#  'zigzagoon': 804,
#  'zoroark': 805,
#  'zorua': 806,
#  'zubat': 807,
#  'zweilous': 808,
#  'zygarde-50': 809}

# %% [markdown]
# ### Paths for images and labels

# %%
images = []
labels = []

for class_name in os.listdir(DATA_PATH):
    for img in os.listdir(DATA_PATH):
        if img.endswith(".jpeg") or img.endswith(".png"):
            images.append(DATA_PATH + img)
            labels.append(class2idx[class_name.split('.')[0].lower()])

# %%
pd.Series(labels).nunique()
# Out:
# 810

# %% [markdown]
# ## Create Dataset

# %%
IMG_SIZE = 160
BATCH_SIZE = 8
SHUFFLE_BUFFER = 100

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42, stratify = labels)

# %%
X_test
# Out:
# ['../archive (1)/images/images/yanma.png',
#  '../archive (1)/images/images/feebas.png',
#  '../archive (1)/images/images/farfetchd.png',
#  '../archive (1)/images/images/pignite.png',
#  '../archive (1)/images/images/bronzong.png',
#  '../archive (1)/images/images/raichu.png',
#  '../archive (1)/images/images/clawitzer.png',
#  '../archive (1)/images/images/rapidash.png',
#  '../archive (1)/images/images/serperior.png',
#  '../archive (1)/images/images/luxray.png',
#  '../archive (1)/images/images/quilladin.png',
#  '../archive (1)/images/images/bouffalant.png',
#  '../archive (1)/images/images/wobbuffet.png',
#  '../archive (1)/images/images/flygon.png',
#  '../archive (1)/images/images/tyranitar.png',
#  '../archive (1)/images/images/nidoran-m.png',
#  '../archive (1)/images/images/ledian.png',
#  '../archive (1)/images/images/aegislash-blade.png',
#  '../archive (1)/images/images/wailmer.png',
#  '../archive (1)/images/images/scatterbug.png',
#  '../archive (1)/images/images/anorith.png',
#  '../archive (1)/images/images/cinccino.png',
#  '../archive (1)/images/images/cascoon.png',
#  '../archive (1)/images/images/swirlix.png',
#  '../archive (1)/images/images/snivy.png',
#  '../archive (1)/images/images/dratini.png',
#  '../archive (1)/images/images/mew.png',
#  '../archive (1)/images/images/goldeen.png',
#  '../archive (1)/images/images/cherubi.png',
#  '../archive (1)/images/images/cofagrigus.png',
#  '../archive (1)/images/images/arceus.png',
#  '../archive (1)/images/images/chandelure.png',
#  '../archive (1)/images/images/hawlucha.png',
#  '../archive (1)/images/images/beheeyem.png',
#  '../archive (1)/images/images/happiny.png',
#  '../archive (1)/images/images/blastoise.png',
#  '../archive (1)/images/images/whiscash.png',
#  '../archive (1)/images/images/kadabra.png',
#  '../archive (1)/images/images/blissey.png',
#  '../archive (1)/images/images/shedinja.png',
#  '../archive (1)/images/images/rhydon.png',
#  '../archive (1)/images/images/fennekin.png',
#  '../archive (1)/images/images/wingull.png',
#  '../archive (1)/images/images/honedge.png',
#  '../archive (1)/images/images/bastiodon.png',
#  '../archive (1)/images/images/abra.png',
#  '../archive (1)/images/images/crustle.png',
#  '../archive (1)/images/images/snorunt.png',
#  '../archive (1)/images/images/cottonee.png',
#  '../archive (1)/images/images/cacturne.png',
#  '../archive (1)/images/images/probopass.png',
#  '../archive (1)/images/images/drifblim.png',
#  '../archive (1)/images/images/haunter.png',
#  '../archive (1)/images/images/regirock.png',
#  '../archive (1)/images/images/dialga.png',
#  '../archive (1)/images/images/eevee.png',
#  '../archive (1)/images/images/inkay.png',
#  '../archive (1)/images/images/thundurus-incarnate.png',
#  '../archive (1)/images/images/exeggcute.png',
#  '../archive (1)/images/images/axew.png',
#  '../archive (1)/images/images/fearow.png',
#  '../archive (1)/images/images/terrakion.png',
#  '../archive (1)/images/images/ambipom.png',
#  '../archive (1)/images/images/feraligatr.png',
#  '../archive (1)/images/images/makuhita.png',
#  '../archive (1)/images/images/accelgor.png',
#  '../archive (1)/images/images/greninja.png',
#  '../archive (1)/images/images/dunsparce.png',
#  '../archive (1)/images/images/magneton.png',
#  '../archive (1)/images/images/maractus.png',
#  '../archive (1)/images/images/sunkern.png',
#  '../archive (1)/images/images/kabutops.png',
#  '../archive (1)/images/images/braviary.png',
#  '../archive (1)/images/images/piloswine.png',
#  '../archive (1)/images/images/walrein.png',
#  '../archive (1)/images/images/alomomola.png',
#  '../archive (1)/images/images/gardevoir.png',
#  '../archive (1)/images/images/lileep.png',
#  '../archive (1)/images/images/torterra.png',
#  '../archive (1)/images/images/audino.png',
#  '../archive (1)/images/images/roserade.png',
#  '../archive (1)/images/images/hitmonlee.png',
#  '../archive (1)/images/images/dratini.png',
#  '../archive (1)/images/images/emolga.png',
#  '../archive (1)/images/images/crobat.png',
#  '../archive (1)/images/images/volcarona.png',
#  '../archive (1)/images/images/latias.png',
#  '../archive (1)/images/images/linoone.png',
#  '../archive (1)/images/images/boldore.png',
#  '../archive (1)/images/images/alakazam.png',
#  '../archive (1)/images/images/jynx.png',
#  '../archive (1)/images/images/deoxys-normal.png',
#  '../archive (1)/images/images/musharna.png',
#  '../archive (1)/images/images/rayquaza.png',
#  '../archive (1)/images/images/lilligant.png',
#  '../archive (1)/images/images/dusknoir.png',
#  '../archive (1)/images/images/hawlucha.png',
#  '../archive (1)/images/images/mankey.png',
#  '../archive (1)/images/images/wynaut.png',
#  '../archive (1)/images/images/fletchinder.png',
#  '../archive (1)/images/images/igglybuff.png',
#  '../archive (1)/images/images/remoraid.png',
#  '../archive (1)/images/images/noibat.png',
#  '../archive (1)/images/images/happiny.png',
#  '../archive (1)/images/images/krookodile.png',
#  '../archive (1)/images/images/chikorita.png',
#  '../archive (1)/images/images/skrelp.png',
#  '../archive (1)/images/images/amaura.png',
#  '../archive (1)/images/images/tirtouga.png',
#  '../archive (1)/images/images/cranidos.png',
#  '../archive (1)/images/images/kricketot.png',
#  '../archive (1)/images/images/axew.png',
#  '../archive (1)/images/images/munna.png',
#  '../archive (1)/images/images/celebi.png',
#  '../archive (1)/images/images/diggersby.png',
#  '../archive (1)/images/images/squirtle.png',
#  '../archive (1)/images/images/infernape.png',
#  '../archive (1)/images/images/snubbull.png',
#  '../archive (1)/images/images/swablu.png',
#  '../archive (1)/images/images/onix.png',
#  '../archive (1)/images/images/cryogonal.png',
#  '../archive (1)/images/images/ledyba.png',
#  '../archive (1)/images/images/pinsir.png',
#  '../archive (1)/images/images/zoroark.png',
#  '../archive (1)/images/images/crobat.png',
#  '../archive (1)/images/images/meowth.png',
#  '../archive (1)/images/images/rampardos.png',
#  '../archive (1)/images/images/pidgey.png',
#  '../archive (1)/images/images/staravia.png',
#  '../archive (1)/images/images/blaziken.png',
#  '../archive (1)/images/images/chansey.png',
#  '../archive (1)/images/images/litleo.png',
#  '../archive (1)/images/images/aerodactyl.png',
#  '../archive (1)/images/images/mienfoo.png',
#  '../archive (1)/images/images/houndoom.png',
#  '../archive (1)/images/images/gastrodon.png',
#  '../archive (1)/images/images/darmanitan-standard.png',
#  '../archive (1)/images/images/lopunny.png',
#  '../archive (1)/images/images/vanilluxe.png',
#  '../archive (1)/images/images/combusken.png',
#  '../archive (1)/images/images/swirlix.png',
#  '../archive (1)/images/images/natu.png',
#  '../archive (1)/images/images/patrat.png',
#  '../archive (1)/images/images/pawniard.png',
#  '../archive (1)/images/images/alomomola.png',
#  '../archive (1)/images/images/thundurus-incarnate.png',
#  '../archive (1)/images/images/kricketune.png',
#  '../archive (1)/images/images/floatzel.png',
#  '../archive (1)/images/images/marshtomp.png',
#  '../archive (1)/images/images/shinx.png',
#  '../archive (1)/images/images/trapinch.png',
#  '../archive (1)/images/images/totodile.png',
#  '../archive (1)/images/images/mew.png',
#  '../archive (1)/images/images/riolu.png',
#  '../archive (1)/images/images/virizion.png',
#  '../archive (1)/images/images/ursaring.png',
#  '../archive (1)/images/images/kakuna.png',
#  '../archive (1)/images/images/combusken.png',
#  '../archive (1)/images/images/granbull.png',
#  '../archive (1)/images/images/tranquill.png',
#  '../archive (1)/images/images/maractus.png',
#  '../archive (1)/images/images/skorupi.png',
#  '../archive (1)/images/images/magnemite.png',
#  '../archive (1)/images/images/golett.png',
#  '../archive (1)/images/images/oshawott.png',
#  '../archive (1)/images/images/magby.png',
#  '../archive (1)/images/images/chinchou.png',
#  '../archive (1)/images/images/jolteon.png',
#  '../archive (1)/images/images/whiscash.png',
#  '../archive (1)/images/images/mamoswine.png',
#  '../archive (1)/images/images/tentacruel.png',
#  '../archive (1)/images/images/hippowdon.png',
#  '../archive (1)/images/images/metapod.png',
#  '../archive (1)/images/images/spiritomb.png',
#  '../archive (1)/images/images/timburr.png',
#  '../archive (1)/images/images/drapion.png',
#  '../archive (1)/images/images/torkoal.png',
#  '../archive (1)/images/images/dewgong.png',
#  '../archive (1)/images/images/tepig.png',
#  '../archive (1)/images/images/electivire.png',
#  '../archive (1)/images/images/kirlia.png',
#  '../archive (1)/images/images/ekans.png',
#  '../archive (1)/images/images/treecko.png',
#  '../archive (1)/images/images/whiscash.png',
#  '../archive (1)/images/images/clamperl.png',
#  '../archive (1)/images/images/palpitoad.png',
#  '../archive (1)/images/images/grimer.png',
#  '../archive (1)/images/images/absol.png',
#  '../archive (1)/images/images/ninetales.png',
#  '../archive (1)/images/images/mamoswine.png',
#  '../archive (1)/images/images/mienshao.png',
#  '../archive (1)/images/images/octillery.png',
#  '../archive (1)/images/images/lairon.png',
#  '../archive (1)/images/images/bergmite.png',
#  '../archive (1)/images/images/sandslash.png',
#  '../archive (1)/images/images/bergmite.png',
#  '../archive (1)/images/images/blitzle.png',
#  '../archive (1)/images/images/rayquaza.png',
#  '../archive (1)/images/images/regirock.png',
#  '../archive (1)/images/images/weezing.png',
#  '../archive (1)/images/images/swalot.png',
#  '../archive (1)/images/images/ferrothorn.png',
#  '../archive (1)/images/images/rayquaza.png',
#  '../archive (1)/images/images/gulpin.png',
#  '../archive (1)/images/images/lombre.png',
#  '../archive (1)/images/images/galvantula.png',
#  '../archive (1)/images/images/wynaut.png',
#  '../archive (1)/images/images/weavile.png',
#  '../archive (1)/images/images/whimsicott.png',
#  '../archive (1)/images/images/venusaur.png',
#  '../archive (1)/images/images/shuckle.png',
#  '../archive (1)/images/images/noivern.png',
#  '../archive (1)/images/images/sylveon.png',
#  '../archive (1)/images/images/graveler.png',
#  '../archive (1)/images/images/sentret.png',
#  '../archive (1)/images/images/combee.png',
#  '../archive (1)/images/images/chatot.png',
#  '../archive (1)/images/images/audino.png',
#  '../archive (1)/images/images/magcargo.png',
#  '../archive (1)/images/images/regigigas.png',
#  '../archive (1)/images/images/amoonguss.png',
#  '../archive (1)/images/images/gothita.png',
#  '../archive (1)/images/images/aipom.png',
#  '../archive (1)/images/images/quilladin.png',
#  '../archive (1)/images/images/lotad.png',
#  '../archive (1)/images/images/latias.png',
#  '../archive (1)/images/images/woobat.png',
#  '../archive (1)/images/images/growlithe.png',
#  '../archive (1)/images/images/skarmory.png',
#  '../archive (1)/images/images/chesnaught.png',
#  '../archive (1)/images/images/vaporeon.png',
#  '../archive (1)/images/images/mareep.png',
#  '../archive (1)/images/images/snubbull.png',
#  '../archive (1)/images/images/ho-oh.png',
#  '../archive (1)/images/images/zorua.png',
#  '../archive (1)/images/images/honedge.png',
#  '../archive (1)/images/images/landorus-incarnate.png',
#  '../archive (1)/images/images/combee.png',
#  '../archive (1)/images/images/natu.png',
#  '../archive (1)/images/images/delibird.png',
#  '../archive (1)/images/images/ninetales.png',
#  '../archive (1)/images/images/beedrill.png',
#  '../archive (1)/images/images/swoobat.png',
#  '../archive (1)/images/images/kecleon.png',
#  '../archive (1)/images/images/taillow.png',
#  '../archive (1)/images/images/litwick.png',
#  '../archive (1)/images/images/remoraid.png',
#  '../archive (1)/images/images/remoraid.png',
#  '../archive (1)/images/images/cobalion.png',
#  '../archive (1)/images/images/watchog.png',
#  '../archive (1)/images/images/dugtrio.png',
#  '../archive (1)/images/images/shinx.png',
#  '../archive (1)/images/images/bagon.png',
#  '../archive (1)/images/images/staryu.png',
#  '../archive (1)/images/images/mantyke.png',
#  '../archive (1)/images/images/furfrou.png',
#  '../archive (1)/images/images/growlithe.png',
#  '../archive (1)/images/images/musharna.png',
#  '../archive (1)/images/images/mawile.png',
#  '../archive (1)/images/images/darmanitan-standard.png',
#  '../archive (1)/images/images/corsola.png',
#  '../archive (1)/images/images/gengar.png',
#  '../archive (1)/images/images/clefairy.png',
#  '../archive (1)/images/images/shellos.png',
#  '../archive (1)/images/images/servine.png',
#  '../archive (1)/images/images/amoonguss.png',
#  '../archive (1)/images/images/clamperl.png',
#  '../archive (1)/images/images/audino.png',
#  '../archive (1)/images/images/greninja.png',
#  '../archive (1)/images/images/panpour.png',
#  '../archive (1)/images/images/binacle.png',
#  '../archive (1)/images/images/meditite.png',
#  '../archive (1)/images/images/carracosta.png',
#  '../archive (1)/images/images/skiddo.png',
#  '../archive (1)/images/images/fennekin.png',
#  '../archive (1)/images/images/slowpoke.png',
#  '../archive (1)/images/images/sunflora.png',
#  '../archive (1)/images/images/unown.png',
#  '../archive (1)/images/images/drapion.png',
#  '../archive (1)/images/images/reuniclus.png',
#  '../archive (1)/images/images/azumarill.png',
#  '../archive (1)/images/images/tyrunt.png',
#  '../archive (1)/images/images/mantine.png',
#  '../archive (1)/images/images/linoone.png',
#  '../archive (1)/images/images/treecko.png',
#  '../archive (1)/images/images/donphan.png',
#  '../archive (1)/images/images/frillish.png',
#  '../archive (1)/images/images/klinklang.png',
#  '../archive (1)/images/images/azurill.png',
#  '../archive (1)/images/images/ampharos.png',
#  '../archive (1)/images/images/buneary.png',
#  '../archive (1)/images/images/silcoon.png',
#  '../archive (1)/images/images/grumpig.png',
#  '../archive (1)/images/images/swadloon.png',
#  '../archive (1)/images/images/garchomp.png',
#  '../archive (1)/images/images/bellsprout.png',
#  '../archive (1)/images/images/bayleef.png',
#  '../archive (1)/images/images/gorebyss.png',
#  '../archive (1)/images/images/raikou.png',
#  '../archive (1)/images/images/dodrio.png',
#  '../archive (1)/images/images/purrloin.png',
#  '../archive (1)/images/images/smoochum.png',
#  '../archive (1)/images/images/numel.png',
#  '../archive (1)/images/images/vaporeon.png',
#  '../archive (1)/images/images/vanilluxe.png',
#  '../archive (1)/images/images/zubat.png',
#  '../archive (1)/images/images/glameow.png',
#  '../archive (1)/images/images/aipom.png',
#  '../archive (1)/images/images/bagon.png',
#  '../archive (1)/images/images/hoppip.png',
#  '../archive (1)/images/images/rhyperior.png',
#  '../archive (1)/images/images/venonat.png',
#  '../archive (1)/images/images/ambipom.png',
#  '../archive (1)/images/images/trapinch.png',
#  '../archive (1)/images/images/aipom.png',
#  '../archive (1)/images/images/delphox.png',
#  '../archive (1)/images/images/suicune.png',
#  '../archive (1)/images/images/gurdurr.png',
#  '../archive (1)/images/images/seviper.png',
#  '../archive (1)/images/images/clefable.png',
#  '../archive (1)/images/images/shuppet.png',
#  '../archive (1)/images/images/anorith.png',
#  '../archive (1)/images/images/blastoise.png',
#  '../archive (1)/images/images/banette.png',
#  '../archive (1)/images/images/slaking.png',
#  '../archive (1)/images/images/furret.png',
#  '../archive (1)/images/images/galvantula.png',
#  '../archive (1)/images/images/beldum.png',
#  '../archive (1)/images/images/sawk.png',
#  '../archive (1)/images/images/dragonite.png',
#  '../archive (1)/images/images/kingler.png',
#  '../archive (1)/images/images/electabuzz.png',
#  '../archive (1)/images/images/noivern.png',
#  '../archive (1)/images/images/chimchar.png',
#  '../archive (1)/images/images/latios.png',
#  '../archive (1)/images/images/tranquill.png',
#  '../archive (1)/images/images/cubchoo.png',
#  '../archive (1)/images/images/wobbuffet.png',
#  '../archive (1)/images/images/whismur.png',
#  '../archive (1)/images/images/electivire.png',
#  '../archive (1)/images/images/golduck.png',
#  '../archive (1)/images/images/gulpin.png',
#  '../archive (1)/images/images/munchlax.png',
#  '../archive (1)/images/images/klinklang.png',
#  '../archive (1)/images/images/darkrai.png',
#  '../archive (1)/images/images/magikarp.png',
#  '../archive (1)/images/images/bellossom.png',
#  '../archive (1)/images/images/virizion.png',
#  '../archive (1)/images/images/donphan.png',
#  '../archive (1)/images/images/yanmega.png',
#  '../archive (1)/images/images/pidove.png',
#  '../archive (1)/images/images/emolga.png',
#  '../archive (1)/images/images/pancham.png',
#  '../archive (1)/images/images/yamask.png',
#  '../archive (1)/images/images/houndoom.png',
#  '../archive (1)/images/images/aron.png',
#  '../archive (1)/images/images/lombre.png',
#  '../archive (1)/images/images/woobat.png',
#  '../archive (1)/images/images/eevee.png',
#  '../archive (1)/images/images/togepi.png',
#  '../archive (1)/images/images/helioptile.png',
#  '../archive (1)/images/images/jellicent.png',
#  '../archive (1)/images/images/garchomp.png',
#  '../archive (1)/images/images/blaziken.png',
#  '../archive (1)/images/images/rayquaza.png',
#  '../archive (1)/images/images/bouffalant.png',
#  '../archive (1)/images/images/corsola.png',
#  '../archive (1)/images/images/woobat.png',
#  '../archive (1)/images/images/illumise.png',
#  '../archive (1)/images/images/pelipper.png',
#  '../archive (1)/images/images/charizard.png',
#  '../archive (1)/images/images/dratini.png',
#  '../archive (1)/images/images/mawile.png',
#  '../archive (1)/images/images/azelf.png',
#  '../archive (1)/images/images/alakazam.png',
#  '../archive (1)/images/images/vivillon.png',
#  '../archive (1)/images/images/electrike.png',
#  '../archive (1)/images/images/golduck.png',
#  '../archive (1)/images/images/geodude.png',
#  '../archive (1)/images/images/simipour.png',
#  '../archive (1)/images/images/vaporeon.png',
#  '../archive (1)/images/images/gigalith.png',
#  '../archive (1)/images/images/aipom.png',
#  '../archive (1)/images/images/magneton.png',
#  '../archive (1)/images/images/chansey.png',
#  '../archive (1)/images/images/braviary.png',
#  '../archive (1)/images/images/zigzagoon.png',
#  '../archive (1)/images/images/sylveon.png',
#  '../archive (1)/images/images/wooper.png',
#  '../archive (1)/images/images/porygon-z.png',
#  '../archive (1)/images/images/herdier.png',
#  '../archive (1)/images/images/tyranitar.png',
#  '../archive (1)/images/images/leavanny.png',
#  '../archive (1)/images/images/deerling.png',
#  '../archive (1)/images/images/bunnelby.png',
#  '../archive (1)/images/images/mesprit.png',
#  '../archive (1)/images/images/honchkrow.png',
#  '../archive (1)/images/images/exeggutor.png',
#  '../archive (1)/images/images/mawile.png',
#  '../archive (1)/images/images/seismitoad.png',
#  '../archive (1)/images/images/crawdaunt.png',
#  '../archive (1)/images/images/magikarp.png',
#  '../archive (1)/images/images/raticate.png',
#  '../archive (1)/images/images/lickilicky.png',
#  '../archive (1)/images/images/mareep.png',
#  '../archive (1)/images/images/houndoom.png',
#  '../archive (1)/images/images/marshtomp.png',
#  '../archive (1)/images/images/flareon.png',
#  '../archive (1)/images/images/treecko.png',
#  '../archive (1)/images/images/spinarak.png',
#  '../archive (1)/images/images/scyther.png',
#  '../archive (1)/images/images/goomy.png',
#  '../archive (1)/images/images/feebas.png',
#  '../archive (1)/images/images/ferrothorn.png',
#  '../archive (1)/images/images/pidgeot.png',
#  '../archive (1)/images/images/clefairy.png',
#  '../archive (1)/images/images/pupitar.png',
#  '../archive (1)/images/images/pidgeotto.png',
#  '../archive (1)/images/images/chimecho.png',
#  '../archive (1)/images/images/noctowl.png',
#  '../archive (1)/images/images/xatu.png',
#  '../archive (1)/images/images/voltorb.png',
#  '../archive (1)/images/images/venusaur.png',
#  '../archive (1)/images/images/armaldo.png',
#  '../archive (1)/images/images/rufflet.png',
#  '../archive (1)/images/images/simisage.png',
#  '../archive (1)/images/images/poliwrath.png',
#  '../archive (1)/images/images/prinplup.png',
#  '../archive (1)/images/images/vanillish.png',
#  '../archive (1)/images/images/hitmontop.png',
#  '../archive (1)/images/images/wurmple.png',
#  '../archive (1)/images/images/taillow.png',
#  '../archive (1)/images/images/skorupi.png',
#  '../archive (1)/images/images/hariyama.png',
#  '../archive (1)/images/images/quilladin.png',
#  '../archive (1)/images/images/larvitar.png',
#  '../archive (1)/images/images/conkeldurr.png',
#  '../archive (1)/images/images/archeops.png',
#  '../archive (1)/images/images/feraligatr.png',
#  '../archive (1)/images/images/clamperl.png',
#  '../archive (1)/images/images/elgyem.png',
#  '../archive (1)/images/images/ralts.png',
#  '../archive (1)/images/images/venomoth.png',
#  '../archive (1)/images/images/diglett.png',
#  '../archive (1)/images/images/spewpa.png',
#  '../archive (1)/images/images/salamence.png',
#  '../archive (1)/images/images/gigalith.png',
#  '../archive (1)/images/images/maractus.png',
#  '../archive (1)/images/images/ariados.png',
#  '../archive (1)/images/images/alomomola.png',
#  '../archive (1)/images/images/electrike.png',
#  '../archive (1)/images/images/venipede.png',
#  '../archive (1)/images/images/sudowoodo.png',
#  '../archive (1)/images/images/tympole.png',
#  '../archive (1)/images/images/darmanitan-standard.png',
#  '../archive (1)/images/images/landorus-incarnate.png',
#  '../archive (1)/images/images/teddiursa.png',
#  '../archive (1)/images/images/kyurem.png',
#  '../archive (1)/images/images/gible.png',
#  '../archive (1)/images/images/teddiursa.png',
#  '../archive (1)/images/images/metapod.png',
#  '../archive (1)/images/images/tangrowth.png',
#  '../archive (1)/images/images/whiscash.png',
#  '../archive (1)/images/images/pidgeot.png',
#  '../archive (1)/images/images/magmortar.png',
#  '../archive (1)/images/images/golbat.png',
#  '../archive (1)/images/images/zangoose.png',
#  '../archive (1)/images/images/pawniard.png',
#  '../archive (1)/images/images/paras.png',
#  '../archive (1)/images/images/riolu.png',
#  '../archive (1)/images/images/houndour.png',
#  '../archive (1)/images/images/seviper.png',
#  '../archive (1)/images/images/kricketune.png',
#  '../archive (1)/images/images/eevee.png',
#  '../archive (1)/images/images/archeops.png',
#  '../archive (1)/images/images/rhyhorn.png',
#  '../archive (1)/images/images/shellos.png',
#  '../archive (1)/images/images/cleffa.png',
#  '../archive (1)/images/images/registeel.png',
#  '../archive (1)/images/images/tirtouga.png',
#  '../archive (1)/images/images/dewgong.png',
#  '../archive (1)/images/images/marshtomp.png',
#  '../archive (1)/images/images/porygon-z.png',
#  '../archive (1)/images/images/slugma.png',
#  '../archive (1)/images/images/leafeon.png',
#  '../archive (1)/images/images/abra.png',
#  '../archive (1)/images/images/banette.png',
#  '../archive (1)/images/images/octillery.png',
#  '../archive (1)/images/images/reuniclus.png',
#  '../archive (1)/images/images/pawniard.png',
#  '../archive (1)/images/images/girafarig.png',
#  '../archive (1)/images/images/snorunt.png',
#  '../archive (1)/images/images/pyroar.png',
#  '../archive (1)/images/images/tympole.png',
#  '../archive (1)/images/images/nidorina.png',
#  '../archive (1)/images/images/vanillite.png',
#  '../archive (1)/images/images/simisage.png',
#  '../archive (1)/images/images/tentacool.png',
#  '../archive (1)/images/images/noctowl.png',
#  '../archive (1)/images/images/shelmet.png',
#  '../archive (1)/images/images/porygon.png',
#  '../archive (1)/images/images/pidgeotto.png',
#  '../archive (1)/images/images/yanma.png',
#  '../archive (1)/images/images/probopass.png',
#  '../archive (1)/images/images/primeape.png',
#  '../archive (1)/images/images/cinccino.png',
#  '../archive (1)/images/images/electrode.png',
#  '../archive (1)/images/images/feebas.png',
#  '../archive (1)/images/images/kricketune.png',
#  '../archive (1)/images/images/swablu.png',
#  '../archive (1)/images/images/slaking.png',
#  '../archive (1)/images/images/chimecho.png',
#  '../archive (1)/images/images/chandelure.png',
#  '../archive (1)/images/images/froakie.png',
#  '../archive (1)/images/images/tyrunt.png',
#  '../archive (1)/images/images/vulpix.png',
#  '../archive (1)/images/images/venonat.png',
#  '../archive (1)/images/images/yveltal.png',
#  '../archive (1)/images/images/gothitelle.png',
#  '../archive (1)/images/images/ledian.png',
#  '../archive (1)/images/images/blitzle.png',
#  '../archive (1)/images/images/geodude.png',
#  '../archive (1)/images/images/ninjask.png',
#  '../archive (1)/images/images/shelgon.png',
#  '../archive (1)/images/images/ponyta.png',
#  '../archive (1)/images/images/ampharos.png',
#  '../archive (1)/images/images/vespiquen.png',
#  '../archive (1)/images/images/hitmonlee.png',
#  '../archive (1)/images/images/prinplup.png',
#  '../archive (1)/images/images/goldeen.png',
#  '../archive (1)/images/images/mismagius.png',
#  '../archive (1)/images/images/cascoon.png',
#  '../archive (1)/images/images/kirlia.png',
#  '../archive (1)/images/images/shellder.png',
#  '../archive (1)/images/images/gastrodon.png',
#  '../archive (1)/images/images/clefairy.png',
#  '../archive (1)/images/images/natu.png',
#  '../archive (1)/images/images/spearow.png',
#  '../archive (1)/images/images/terrakion.png',
#  '../archive (1)/images/images/basculin-red-striped.png',
#  '../archive (1)/images/images/nidoran-m.png',
#  '../archive (1)/images/images/carnivine.png',
#  '../archive (1)/images/images/yanma.png',
#  '../archive (1)/images/images/whiscash.png',
#  '../archive (1)/images/images/whimsicott.png',
#  '../archive (1)/images/images/malamar.png',
#  '../archive (1)/images/images/volcarona.png',
#  '../archive (1)/images/images/forretress.png',
#  '../archive (1)/images/images/avalugg.png',
#  '../archive (1)/images/images/deino.png',
#  '../archive (1)/images/images/bellossom.png',
#  '../archive (1)/images/images/bisharp.png',
#  '../archive (1)/images/images/hitmonchan.png',
#  '../archive (1)/images/images/yanmega.png',
#  '../archive (1)/images/images/simisage.png',
#  '../archive (1)/images/images/clawitzer.png',
#  '../archive (1)/images/images/buizel.png',
#  '../archive (1)/images/images/wobbuffet.png',
#  '../archive (1)/images/images/tangrowth.png',
#  '../archive (1)/images/images/glaceon.png',
#  '../archive (1)/images/images/whismur.png',
#  '../archive (1)/images/images/espurr.png',
#  '../archive (1)/images/images/ludicolo.png',
#  '../archive (1)/images/images/jellicent.png',
#  '../archive (1)/images/images/terrakion.png',
#  '../archive (1)/images/images/charizard.png',
#  '../archive (1)/images/images/chimecho.png',
#  '../archive (1)/images/images/stantler.png',
#  '../archive (1)/images/images/beautifly.png',
#  '../archive (1)/images/images/cradily.png',
#  '../archive (1)/images/images/geodude.png',
#  '../archive (1)/images/images/flaaffy.png',
#  '../archive (1)/images/images/illumise.png',
#  '../archive (1)/images/images/chikorita.png',
#  '../archive (1)/images/images/stunfisk.png',
#  '../archive (1)/images/images/ferrothorn.png',
#  '../archive (1)/images/images/hoothoot.png',
#  '../archive (1)/images/images/porygon2.png',
#  '../archive (1)/images/images/kecleon.png',
#  '../archive (1)/images/images/darumaka.png',
#  '../archive (1)/images/images/wailmer.png',
#  '../archive (1)/images/images/illumise.png',
#  '../archive (1)/images/images/ampharos.png',
#  '../archive (1)/images/images/cottonee.png',
#  '../archive (1)/images/images/caterpie.png',
#  '../archive (1)/images/images/gigalith.png',
#  '../archive (1)/images/images/togekiss.png',
#  '../archive (1)/images/images/aipom.png',
#  '../archive (1)/images/images/sharpedo.png',
#  '../archive (1)/images/images/mareep.png',
#  '../archive (1)/images/images/dwebble.png',
#  '../archive (1)/images/images/mightyena.png',
#  '../archive (1)/images/images/lapras.png',
#  '../archive (1)/images/images/archeops.png',
#  '../archive (1)/images/images/spiritomb.png',
#  '../archive (1)/images/images/rattata.png',
#  '../archive (1)/images/images/spearow.png',
#  '../archive (1)/images/images/togetic.png',
#  '../archive (1)/images/images/skuntank.png',
#  '../archive (1)/images/images/shieldon.png',
#  '../archive (1)/images/images/celebi.png',
#  '../archive (1)/images/images/chesnaught.png',
#  '../archive (1)/images/images/froslass.png',
#  '../archive (1)/images/images/swalot.png',
#  '../archive (1)/images/images/duosion.png',
#  '../archive (1)/images/images/omanyte.png',
#  '../archive (1)/images/images/heliolisk.png',
#  '../archive (1)/images/images/mime-jr.png',
#  '../archive (1)/images/images/makuhita.png',
#  '../archive (1)/images/images/natu.png',
#  '../archive (1)/images/images/palpitoad.png',
#  '../archive (1)/images/images/unfezant.png',
#  '../archive (1)/images/images/miltank.png',
#  '../archive (1)/images/images/conkeldurr.png',
#  '../archive (1)/images/images/servine.png',
#  '../archive (1)/images/images/raticate.png',
#  '../archive (1)/images/images/spinarak.png',
#  '../archive (1)/images/images/tyrunt.png',
#  '../archive (1)/images/images/staravia.png',
#  '../archive (1)/images/images/blaziken.png',
#  '../archive (1)/images/images/duosion.png',
#  '../archive (1)/images/images/reuniclus.png',
#  '../archive (1)/images/images/nidorina.png',
#  '../archive (1)/images/images/purugly.png',
#  '../archive (1)/images/images/roggenrola.png',
#  '../archive (1)/images/images/growlithe.png',
#  '../archive (1)/images/images/aerodactyl.png',
#  '../archive (1)/images/images/slakoth.png',
#  '../archive (1)/images/images/monferno.png',
#  '../archive (1)/images/images/houndoom.png',
#  '../archive (1)/images/images/tentacruel.png',
#  '../archive (1)/images/images/charizard.png',
#  '../archive (1)/images/images/nidoking.png',
#  '../archive (1)/images/images/grumpig.png',
#  '../archive (1)/images/images/oshawott.png',
#  '../archive (1)/images/images/tympole.png',
#  '../archive (1)/images/images/piloswine.png',
#  '../archive (1)/images/images/raticate.png',
#  '../archive (1)/images/images/grotle.png',
#  '../archive (1)/images/images/electivire.png',
#  '../archive (1)/images/images/scatterbug.png',
#  '../archive (1)/images/images/mismagius.png',
#  '../archive (1)/images/images/honchkrow.png',
#  '../archive (1)/images/images/vivillon.png',
#  '../archive (1)/images/images/electrike.png',
#  '../archive (1)/images/images/cyndaquil.png',
#  '../archive (1)/images/images/bidoof.png',
#  '../archive (1)/images/images/delcatty.png',
#  '../archive (1)/images/images/rhyperior.png',
#  '../archive (1)/images/images/burmy.png',
#  '../archive (1)/images/images/hitmontop.png',
#  '../archive (1)/images/images/bibarel.png',
#  '../archive (1)/images/images/quilava.png',
#  '../archive (1)/images/images/timburr.png',
#  '../archive (1)/images/images/spiritomb.png',
#  '../archive (1)/images/images/floatzel.png',
#  '../archive (1)/images/images/metang.png',
#  '../archive (1)/images/images/rotom.png',
#  '../archive (1)/images/images/haxorus.png',
#  '../archive (1)/images/images/mightyena.png',
#  '../archive (1)/images/images/salamence.png',
#  '../archive (1)/images/images/clefairy.png',
#  '../archive (1)/images/images/typhlosion.png',
#  '../archive (1)/images/images/pyroar.png',
#  '../archive (1)/images/images/eevee.png',
#  '../archive (1)/images/images/duskull.png',
#  '../archive (1)/images/images/sealeo.png',
#  '../archive (1)/images/images/dragalge.png',
#  '../archive (1)/images/images/spinda.png',
#  '../archive (1)/images/images/shelgon.png',
#  '../archive (1)/images/images/vulpix.png',
#  '../archive (1)/images/images/scolipede.png',
#  '../archive (1)/images/images/staryu.png',
#  '../archive (1)/images/images/venonat.png',
#  '../archive (1)/images/images/manaphy.png',
#  '../archive (1)/images/images/remoraid.png',
#  '../archive (1)/images/images/quagsire.png',
#  '../archive (1)/images/images/weavile.png',
#  '../archive (1)/images/images/carbink.png',
#  '../archive (1)/images/images/sigilyph.png',
#  '../archive (1)/images/images/croconaw.png',
#  '../archive (1)/images/images/tauros.png',
#  '../archive (1)/images/images/farfetchd.png',
#  '../archive (1)/images/images/porygon2.png',
#  '../archive (1)/images/images/dunsparce.png',
#  '../archive (1)/images/images/flareon.png',
#  '../archive (1)/images/images/swinub.png',
#  '../archive (1)/images/images/wooper.png',
#  '../archive (1)/images/images/latias.png',
#  '../archive (1)/images/images/sigilyph.png',
#  '../archive (1)/images/images/silcoon.png',
#  '../archive (1)/images/images/stunky.png',
#  '../archive (1)/images/images/salamence.png',
#  '../archive (1)/images/images/stunfisk.png',
#  '../archive (1)/images/images/natu.png',
#  '../archive (1)/images/images/trevenant.png',
#  '../archive (1)/images/images/eelektrik.png',
#  '../archive (1)/images/images/haunter.png',
#  '../archive (1)/images/images/electivire.png',
#  '../archive (1)/images/images/tyrunt.png',
#  '../archive (1)/images/images/vullaby.png',
#  '../archive (1)/images/images/quilladin.png',
#  '../archive (1)/images/images/reuniclus.png',
#  '../archive (1)/images/images/carbink.png',
#  '../archive (1)/images/images/swoobat.png',
#  '../archive (1)/images/images/beheeyem.png',
#  '../archive (1)/images/images/kingler.png',
#  '../archive (1)/images/images/loudred.png',
#  '../archive (1)/images/images/poliwrath.png',
#  '../archive (1)/images/images/vanilluxe.png',
#  '../archive (1)/images/images/hippopotas.png',
#  '../archive (1)/images/images/pumpkaboo-average.png',
#  '../archive (1)/images/images/oddish.png',
#  '../archive (1)/images/images/skarmory.png',
#  '../archive (1)/images/images/pinsir.png',
#  '../archive (1)/images/images/mantine.png',
#  '../archive (1)/images/images/virizion.png',
#  '../archive (1)/images/images/amaura.png',
#  '../archive (1)/images/images/weavile.png',
#  '../archive (1)/images/images/espeon.png',
#  '../archive (1)/images/images/makuhita.png',
#  '../archive (1)/images/images/lairon.png',
#  '../archive (1)/images/images/kyogre.png',
#  '../archive (1)/images/images/mandibuzz.png',
#  '../archive (1)/images/images/litwick.png',
#  '../archive (1)/images/images/klang.png',
#  '../archive (1)/images/images/omastar.png',
#  '../archive (1)/images/images/clawitzer.png',
#  '../archive (1)/images/images/chikorita.png',
#  '../archive (1)/images/images/alomomola.png',
#  '../archive (1)/images/images/magcargo.png',
#  '../archive (1)/images/images/gastrodon.png',
#  '../archive (1)/images/images/zangoose.png',
#  '../archive (1)/images/images/lugia.png',
#  '../archive (1)/images/images/vigoroth.png',
#  '../archive (1)/images/images/krookodile.png',
#  '../archive (1)/images/images/manectric.png',
#  '../archive (1)/images/images/gogoat.png',
#  '../archive (1)/images/images/hydreigon.png',
#  '../archive (1)/images/images/gurdurr.png',
#  '../archive (1)/images/images/reshiram.png',
#  '../archive (1)/images/images/zubat.png',
#  '../archive (1)/images/images/electrode.png',
#  '../archive (1)/images/images/nidorina.png',
#  '../archive (1)/images/images/hoopa-confined.png',
#  '../archive (1)/images/images/ledian.png',
#  '../archive (1)/images/images/gothitelle.png',
#  '../archive (1)/images/images/ledyba.png',
#  '../archive (1)/images/images/zoroark.png',
#  '../archive (1)/images/images/samurott.png',
#  '../archive (1)/images/images/silcoon.png',
#  '../archive (1)/images/images/shelmet.png',
#  '../archive (1)/images/images/glalie.png',
#  '../archive (1)/images/images/zebstrika.png',
#  '../archive (1)/images/images/machamp.png',
#  '../archive (1)/images/images/houndour.png',
#  '../archive (1)/images/images/jolteon.png',
#  '../archive (1)/images/images/sableye.png',
#  '../archive (1)/images/images/leavanny.png',
#  '../archive (1)/images/images/croconaw.png',
#  '../archive (1)/images/images/fearow.png',
#  '../archive (1)/images/images/elekid.png',
#  '../archive (1)/images/images/diggersby.png',
#  '../archive (1)/images/images/banette.png',
#  '../archive (1)/images/images/luxio.png',
#  '../archive (1)/images/images/marill.png',
#  '../archive (1)/images/images/spewpa.png',
#  '../archive (1)/images/images/duskull.png',
#  '../archive (1)/images/images/muk.png',
#  '../archive (1)/images/images/empoleon.png',
#  '../archive (1)/images/images/feebas.png',
#  '../archive (1)/images/images/mudkip.png',
#  '../archive (1)/images/images/ninetales.png',
#  '../archive (1)/images/images/boldore.png',
#  '../archive (1)/images/images/gurdurr.png',
#  '../archive (1)/images/images/flareon.png',
#  '../archive (1)/images/images/stunky.png',
#  '../archive (1)/images/images/alomomola.png',
#  '../archive (1)/images/images/onix.png',
#  '../archive (1)/images/images/litleo.png',
#  '../archive (1)/images/images/hitmonchan.png',
#  '../archive (1)/images/images/probopass.png',
#  '../archive (1)/images/images/chatot.png',
#  '../archive (1)/images/images/sceptile.png',
#  '../archive (1)/images/images/onix.png',
#  '../archive (1)/images/images/registeel.png',
#  '../archive (1)/images/images/shuckle.png',
#  '../archive (1)/images/images/venonat.png',
#  '../archive (1)/images/images/latias.png',
#  '../archive (1)/images/images/monferno.png',
#  '../archive (1)/images/images/golduck.png',
#  '../archive (1)/images/images/raichu.png',
#  '../archive (1)/images/images/scyther.png',
#  '../archive (1)/images/images/grimer.png',
#  '../archive (1)/images/images/ninetales.png',
#  '../archive (1)/images/images/durant.png',
#  '../archive (1)/images/images/carnivine.png',
#  '../archive (1)/images/images/florges.png',
#  '../archive (1)/images/images/grimer.png',
#  '../archive (1)/images/images/amoonguss.png',
#  '../archive (1)/images/images/shroomish.png',
#  '../archive (1)/images/images/seel.png',
#  '../archive (1)/images/images/amoonguss.png',
#  '../archive (1)/images/images/happiny.png',
#  '../archive (1)/images/images/vullaby.png',
#  '../archive (1)/images/images/mudkip.png',
#  '../archive (1)/images/images/ho-oh.png',
#  '../archive (1)/images/images/entei.png',
#  '../archive (1)/images/images/kricketune.png',
#  '../archive (1)/images/images/grimer.png',
#  '../archive (1)/images/images/mienshao.png',
#  '../archive (1)/images/images/cofagrigus.png',
#  '../archive (1)/images/images/deerling.png',
#  '../archive (1)/images/images/chatot.png',
#  '../archive (1)/images/images/pansage.png',
#  '../archive (1)/images/images/chingling.png',
#  '../archive (1)/images/images/doublade.png',
#  '../archive (1)/images/images/flaaffy.png',
#  '../archive (1)/images/images/psyduck.png',
#  '../archive (1)/images/images/hydreigon.png',
#  '../archive (1)/images/images/scrafty.png',
#  '../archive (1)/images/images/zoroark.png',
#  '../archive (1)/images/images/frillish.png',
#  '../archive (1)/images/images/blissey.png',
#  '../archive (1)/images/images/piloswine.png',
#  '../archive (1)/images/images/arceus.png',
#  '../archive (1)/images/images/simisear.png',
#  '../archive (1)/images/images/lanturn.png',
#  '../archive (1)/images/images/porygon-z.png',
#  '../archive (1)/images/images/palkia.png',
#  '../archive (1)/images/images/scolipede.png',
#  '../archive (1)/images/images/machoke.png',
#  '../archive (1)/images/images/manectric.png',
#  '../archive (1)/images/images/sandslash.png',
#  '../archive (1)/images/images/aipom.png',
#  '../archive (1)/images/images/poliwag.png',
#  '../archive (1)/images/images/leafeon.png',
#  '../archive (1)/images/images/girafarig.png',
#  '../archive (1)/images/images/qwilfish.png',
#  '../archive (1)/images/images/tangela.png',
#  '../archive (1)/images/images/kabutops.png',
#  '../archive (1)/images/images/greninja.png',
#  '../archive (1)/images/images/riolu.png',
#  '../archive (1)/images/images/swoobat.png',
#  '../archive (1)/images/images/xerneas.png',
#  '../archive (1)/images/images/ho-oh.png',
#  '../archive (1)/images/images/noctowl.png',
#  '../archive (1)/images/images/ditto.png',
#  '../archive (1)/images/images/goodra.png',
#  '../archive (1)/images/images/palkia.png',
#  '../archive (1)/images/images/wobbuffet.png',
#  '../archive (1)/images/images/vanillish.png',
#  '../archive (1)/images/images/nidoqueen.png',
#  '../archive (1)/images/images/slowking.png',
#  '../archive (1)/images/images/mienshao.png',
#  '../archive (1)/images/images/granbull.png',
#  '../archive (1)/images/images/haunter.png',
#  '../archive (1)/images/images/kingler.png',
#  '../archive (1)/images/images/hoothoot.png',
#  '../archive (1)/images/images/rattata.png',
#  '../archive (1)/images/images/ariados.png',
#  '../archive (1)/images/images/staraptor.png',
#  '../archive (1)/images/images/hawlucha.png',
#  '../archive (1)/images/images/mewtwo.png',
#  '../archive (1)/images/images/darkrai.png',
#  '../archive (1)/images/images/shellder.png',
#  '../archive (1)/images/images/pangoro.png',
#  '../archive (1)/images/images/camerupt.png',
#  '../archive (1)/images/images/bellsprout.png',
#  '../archive (1)/images/images/croconaw.png',
#  '../archive (1)/images/images/gloom.png',
#  '../archive (1)/images/images/baltoy.png',
#  '../archive (1)/images/images/cubchoo.png',
#  '../archive (1)/images/images/mothim.png',
#  '../archive (1)/images/images/typhlosion.png',
#  '../archive (1)/images/images/grimer.png',
#  '../archive (1)/images/images/beartic.png',
#  '../archive (1)/images/images/pineco.png',
#  '../archive (1)/images/images/smeargle.png',
#  '../archive (1)/images/images/zubat.png',
#  '../archive (1)/images/images/unown.png',
#  '../archive (1)/images/images/piloswine.png',
#  '../archive (1)/images/images/moltres.png',
#  '../archive (1)/images/images/sunkern.png',
#  '../archive (1)/images/images/aggron.png',
#  '../archive (1)/images/images/hypno.png',
#  '../archive (1)/images/images/exploud.png',
#  '../archive (1)/images/images/furfrou.png',
#  '../archive (1)/images/images/quilava.png',
#  '../archive (1)/images/images/tentacruel.png',
#  '../archive (1)/images/images/togetic.png',
#  '../archive (1)/images/images/skrelp.png',
#  '../archive (1)/images/images/skrelp.png',
#  '../archive (1)/images/images/dialga.png',
#  '../archive (1)/images/images/abra.png',
#  '../archive (1)/images/images/weepinbell.png',
#  '../archive (1)/images/images/whismur.png',
#  '../archive (1)/images/images/magcargo.png',
#  '../archive (1)/images/images/budew.png',
#  '../archive (1)/images/images/golurk.png',
#  '../archive (1)/images/images/hydreigon.png',
#  '../archive (1)/images/images/vileplume.png',
#  '../archive (1)/images/images/clawitzer.png',
#  '../archive (1)/images/images/azelf.png',
#  '../archive (1)/images/images/loudred.png',
#  '../archive (1)/images/images/honchkrow.png',
#  '../archive (1)/images/images/klink.png',
#  '../archive (1)/images/images/kangaskhan.png',
#  '../archive (1)/images/images/nidoqueen.png',
#  '../archive (1)/images/images/arceus.png',
#  '../archive (1)/images/images/buizel.png',
#  '../archive (1)/images/images/lopunny.png',
#  '../archive (1)/images/images/beartic.png',
#  '../archive (1)/images/images/voltorb.png',
#  '../archive (1)/images/images/gengar.png',
#  '../archive (1)/images/images/slaking.png',
#  '../archive (1)/images/images/chimecho.png',
#  '../archive (1)/images/images/dratini.png',
#  '../archive (1)/images/images/snover.png',
#  '../archive (1)/images/images/regice.png',
#  '../archive (1)/images/images/maractus.png',
#  '../archive (1)/images/images/noivern.png',
#  '../archive (1)/images/images/ambipom.png',
#  '../archive (1)/images/images/glaceon.png',
#  '../archive (1)/images/images/linoone.png',
#  '../archive (1)/images/images/hawlucha.png',
#  '../archive (1)/images/images/spoink.png',
#  '../archive (1)/images/images/totodile.png',
#  '../archive (1)/images/images/ampharos.png',
#  '../archive (1)/images/images/arceus.png',
#  '../archive (1)/images/images/electivire.png',
#  '../archive (1)/images/images/diancie.png',
#  '../archive (1)/images/images/swadloon.png',
#  '../archive (1)/images/images/keldeo-ordinary.png',
#  '../archive (1)/images/images/ferrothorn.png',
#  '../archive (1)/images/images/abra.png',
#  '../archive (1)/images/images/bergmite.png',
#  '../archive (1)/images/images/vespiquen.png',
#  '../archive (1)/images/images/krokorok.png',
#  '../archive (1)/images/images/lampent.png',
#  '../archive (1)/images/images/archeops.png',
#  '../archive (1)/images/images/groudon.png',
#  '../archive (1)/images/images/sandshrew.png',
#  '../archive (1)/images/images/wooper.png',
#  '../archive (1)/images/images/tympole.png',
#  '../archive (1)/images/images/luxray.png',
#  '../archive (1)/images/images/abomasnow.png',
#  '../archive (1)/images/images/loudred.png',
#  '../archive (1)/images/images/slaking.png',
#  '../archive (1)/images/images/throh.png',
#  '../archive (1)/images/images/walrein.png',
#  '../archive (1)/images/images/zebstrika.png',
#  '../archive (1)/images/images/buizel.png',
#  '../archive (1)/images/images/lopunny.png',
#  '../archive (1)/images/images/parasect.png',
#  '../archive (1)/images/images/oddish.png',
#  '../archive (1)/images/images/qwilfish.png',
#  '../archive (1)/images/images/magcargo.png',
#  '../archive (1)/images/images/carnivine.png',
#  '../archive (1)/images/images/hawlucha.png',
#  '../archive (1)/images/images/slakoth.png',
#  '../archive (1)/images/images/cobalion.png',
#  '../archive (1)/images/images/natu.png',
#  '../archive (1)/images/images/meditite.png',
#  '../archive (1)/images/images/swellow.png',
#  '../archive (1)/images/images/oddish.png',
#  '../archive (1)/images/images/burmy.png',
#  '../archive (1)/images/images/typhlosion.png',
#  '../archive (1)/images/images/tangrowth.png',
#  '../archive (1)/images/images/golbat.png',
#  '../archive (1)/images/images/growlithe.png',
#  '../archive (1)/images/images/gorebyss.png',
#  '../archive (1)/images/images/fletchling.png',
#  '../archive (1)/images/images/chandelure.png',
#  '../archive (1)/images/images/watchog.png',
#  '../archive (1)/images/images/cleffa.png',
#  '../archive (1)/images/images/skitty.png',
#  '../archive (1)/images/images/torkoal.png',
#  '../archive (1)/images/images/hoothoot.png',
#  '../archive (1)/images/images/corsola.png',
#  '../archive (1)/images/images/gastrodon.png',
#  '../archive (1)/images/images/loudred.png',
#  '../archive (1)/images/images/vanilluxe.png',
#  '../archive (1)/images/images/dragalge.png',
#  '../archive (1)/images/images/nidorina.png',
#  '../archive (1)/images/images/kirlia.png',
#  '../archive (1)/images/images/skarmory.png',
#  '../archive (1)/images/images/salamence.png',
#  '../archive (1)/images/images/kricketot.png',
#  '../archive (1)/images/images/blaziken.png',
#  '../archive (1)/images/images/espurr.png',
#  '../archive (1)/images/images/tyranitar.png',
#  '../archive (1)/images/images/seismitoad.png',
#  '../archive (1)/images/images/seaking.png',
#  '../archive (1)/images/images/lumineon.png',
#  '../archive (1)/images/images/fennekin.png',
#  '../archive (1)/images/images/latias.png',
#  '../archive (1)/images/images/igglybuff.png',
#  '../archive (1)/images/images/kangaskhan.png',
#  '../archive (1)/images/images/gourgeist-average.png',
#  ...]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %%
def decode_img(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_jpeg(img, channels=3)
    # Use `convert_image_dtype` to convert to floats in the [0,1] range.
    img = tf.image.convert_image_dtype(img, tf.float32)
    # resize the image to the desired size.
    return tf.image.resize(img, [IMG_SIZE, IMG_SIZE])


def pre_process_data(file_path, label):
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_dataset = train_dataset.map(pre_process_data)
test_dataset = test_dataset.map(pre_process_data)

# %%
train_dataset
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(160, 160, 3), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))>

# %%
print("Train dataset: ", train_dataset)
print("Test dataset: ", test_dataset)
# Out:
# Train dataset:  <MapDataset element_spec=(TensorSpec(shape=(160, 160, 3), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))>
# Test dataset:  <MapDataset element_spec=(TensorSpec(shape=(160, 160, 3), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))>

# %% [markdown]
# ### Exploratory Analysis

# %%
def get_class_distribution(dataset_obj):
    count_dict = {k:0 for k,v in class2idx.items()}
    
    for _, label_id in dataset_obj:
        label = idx2class[label_id.numpy()]
        count_dict[label] += 1
    return count_dict

# %% [markdown]
# ### Class distribution

# %%
# get_class_distribution(train_dataset)

# %% [markdown]
# ## Train Model

# %% [markdown]
# ### Shuffle and Batch Input Tensors

# %%
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER).batch(BATCH_SIZE, drop_remainder=True)
test_dataset = test_dataset.batch(1)

# %%
train_dataset
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(8, 160, 160, 3), dtype=tf.float32, name=None), TensorSpec(shape=(8,), dtype=tf.int32, name=None))>

# %% [markdown]
# ### Train Classifier Head of PreTrained Model

# %%
num_epochs = 10

# %%
with tf.device("GPU:0"):

    # Create the base model from the pre-trained model MobileNet V2
    base_model = tf.keras.applications.MobileNetV2(input_shape=(IMG_SIZE, IMG_SIZE, 3), include_top=False, weights='imagenet')

    # Freeze the pre-trained model weights
    base_model.trainable = False# Trainable classification head

    maxpool_layer = tf.keras.layers.GlobalMaxPooling2D()

    prediction_layer = tf.keras.layers.Dense(809, activation='softmax')# Layer classification head with feature detector

    model = tf.keras.Sequential([
        base_model,
        maxpool_layer,
        prediction_layer
    ])

    learning_rate = 0.0001# Compile the model

    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr=learning_rate), 
        loss=tf.keras.losses.SparseCategoricalCrossentropy(),
        metrics=['accuracy']
    )
    
    model.fit(
        train_dataset,
        epochs=num_epochs,
    )
# Out:
# Epoch 1/10
# 677/677 [==============================] - 20s 29ms/step - loss: 6.5018 - accuracy: 0.0541
# Epoch 2/10
# 677/677 [==============================] - 20s 29ms/step - loss: 3.4095 - accuracy: 0.2805
# Epoch 3/10
# 677/677 [==============================] - 20s 29ms/step - loss: 2.0407 - accuracy: 0.5157
# Epoch 4/10
# 677/677 [==============================] - 20s 29ms/step - loss: 1.3099 - accuracy: 0.6780
# Epoch 5/10
# 677/677 [==============================] - 20s 29ms/step - loss: 0.8828 - accuracy: 0.7903
# Epoch 6/10
# 677/677 [==============================] - 20s 30ms/step - loss: 0.6035 - accuracy: 0.8737
# Epoch 7/10
# 677/677 [==============================] - 20s 29ms/step - loss: 0.4121 - accuracy: 0.9260
# Epoch 8/10
# 677/677 [==============================] - 20s 29ms/step - loss: 0.2829 - accuracy: 0.9577
# Epoch 9/10
# 677/677 [==============================] - 20s 29ms/step - loss: 0.1912 - accuracy: 0.9790
# Epoch 10/10
# 677/677 [==============================] - 20s 29ms/step - loss: 0.1303 - accuracy: 0.9887

# %%
model.evaluate(test_dataset)
# Out:
# 1355/1355 [==============================] - 6s 4ms/step - loss: 1.5236 - accuracy: 0.6376
# [1.5235544443130493, 0.6376383900642395]

# %% [markdown]
# ### Fine Tune PreTrained Model

# %%
# Unfreeze all layers of MobileNetV2
base_model.trainable = True

# Refreeze layers until the layers we want to fine-tune
for layer in base_model.layers[:100]:
    layer.trainable =  False
    
    
# Use a lower learning rate
lr_finetune = learning_rate / 10

# Recompile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(lr=lr_finetune), 
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)


# Increase training epochs for fine-tuning
fine_tune_epochs = 30

total_epochs =  num_epochs + fine_tune_epochs

# Fine-tune model
# Note: Set initial_epoch to begin training after epoch 30 since we
# previously trained for 30 epochs.
model.fit(train_dataset, 
          epochs=total_epochs, 
          initial_epoch = num_epochs
         )
# Out:
# Epoch 11/40
# 677/677 [==============================] - 23s 34ms/step - loss: 2.2586 - accuracy: 0.4943
# Epoch 12/40
# 677/677 [==============================] - 23s 34ms/step - loss: 1.3818 - accuracy: 0.6377
# Epoch 13/40
# 677/677 [==============================] - 23s 34ms/step - loss: 1.0808 - accuracy: 0.7138
# Epoch 14/40
# 677/677 [==============================] - 24s 35ms/step - loss: 0.8169 - accuracy: 0.7666
# Epoch 15/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.6892 - accuracy: 0.7965
# Epoch 16/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.5620 - accuracy: 0.8359
# Epoch 17/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.4670 - accuracy: 0.8588
# Epoch 18/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.3824 - accuracy: 0.8852
# Epoch 19/40
# 677/677 [==============================] - 23s 35ms/step - loss: 0.3226 - accuracy: 0.9018
# Epoch 20/40
# 677/677 [==============================] - 24s 35ms/step - loss: 0.2651 - accuracy: 0.9193
# Epoch 21/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.2583 - accuracy: 0.9223
# Epoch 22/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.1889 - accuracy: 0.9442
# Epoch 23/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.1827 - accuracy: 0.9448
# Epoch 24/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.1462 - accuracy: 0.9579
# Epoch 25/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.1499 - accuracy: 0.9531
# Epoch 26/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.1353 - accuracy: 0.9627
# Epoch 27/40
# 677/677 [==============================] - 23s 35ms/step - loss: 0.1146 - accuracy: 0.9655
# Epoch 28/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.0888 - accuracy: 0.9764
# Epoch 29/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.0838 - accuracy: 0.9769
# Epoch 30/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.0850 - accuracy: 0.9758
# Epoch 31/40
# 677/677 [==============================] - 23s 35ms/step - loss: 0.0837 - accuracy: 0.9771
# Epoch 32/40
# 677/677 [==============================] - 24s 35ms/step - loss: 0.0639 - accuracy: 0.9843
# Epoch 33/40
# 677/677 [==============================] - 24s 35ms/step - loss: 0.0582 - accuracy: 0.9841
# Epoch 34/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.0623 - accuracy: 0.9832
# Epoch 35/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.0560 - accuracy: 0.9856
# Epoch 36/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.0465 - accuracy: 0.9865
# Epoch 37/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.0423 - accuracy: 0.9900
# Epoch 38/40
# 677/677 [==============================] - 24s 35ms/step - loss: 0.0454 - accuracy: 0.9887
# Epoch 39/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.0440 - accuracy: 0.9886
# Epoch 40/40
# 677/677 [==============================] - 23s 34ms/step - loss: 0.0407 - accuracy: 0.9902

# %%
model.evaluate(test_dataset)
# Out:
# 1355/1355 [==============================] - 6s 4ms/step - loss: 0.8356 - accuracy: 0.8089
# [0.8355814814567566, 0.8088560700416565]

# %%
y_pred = model.predict(test_dataset)

# %%
y_pred_list = []

for i in range(len(y_pred)):
    class_id = np.argmax(y_pred[i])
    y_pred_list.append(class_id)

# %%
print(classification_report(y_test, y_pred_list))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.71      0.63         7
#            1       0.71      0.45      0.56        11
#            2       0.86      0.86      0.86         7
#            3       0.80      0.50      0.62         8
#            4       0.69      0.90      0.78        10
#            5       0.80      0.80      0.80         5
#            6       1.00      0.80      0.89        10
#            7       1.00      1.00      1.00         9
#            8       1.00      0.60      0.75        10
#            9       1.00      0.89      0.94         9
#           10       0.60      0.67      0.63         9
#           11       0.90      1.00      0.95         9
#           12       0.64      0.70      0.67        10
#           13       1.00      0.71      0.83         7
#           14       0.91      0.91      0.91        11
#           15       0.86      0.75      0.80         8
#           16       0.82      1.00      0.90         9
#           17       1.00      0.56      0.71         9
#           18       0.87      1.00      0.93        13
#           19       0.57      0.44      0.50         9
#           20       0.67      0.75      0.71         8
#           21       1.00      0.71      0.83         7
#           22       1.00      0.89      0.94         9
#           23       0.86      0.67      0.75         9
#           24       0.75      0.60      0.67         5
#           25       0.62      0.62      0.62         8
#           26       0.73      1.00      0.84         8
#           27       0.89      1.00      0.94         8
#           28       1.00      0.89      0.94         9
#           29       1.00      0.80      0.89        10
#           30       0.80      0.89      0.84         9
#           31       0.90      1.00      0.95         9
#           32       0.88      0.78      0.82         9
#           33       0.89      0.89      0.89         9
#           34       0.89      0.89      0.89         9
#           35       0.82      1.00      0.90         9
#           36       0.86      0.86      0.86         7
#           37       1.00      0.75      0.86         8
#           38       0.54      0.78      0.64         9
#           39       0.80      0.89      0.84         9
#           40       0.80      0.89      0.84         9
#           41       1.00      0.80      0.89        10
#           42       0.89      0.89      0.89         9
#           43       0.78      0.88      0.82         8
#           44       0.71      0.62      0.67         8
#           45       1.00      1.00      1.00        10
#           46       0.82      0.75      0.78        12
#           47       0.90      0.90      0.90        10
#           48       0.73      0.89      0.80         9
#           49       1.00      0.90      0.95        10
#           50       0.80      0.57      0.67         7
#           51       1.00      0.80      0.89        10
#           52       0.67      0.80      0.73        10
#           53       1.00      0.75      0.86        12
#           54       0.90      0.90      0.90        10
#           55       0.86      0.75      0.80         8
#           56       0.90      0.90      0.90        10
#           57       0.75      0.90      0.82        10
#           58       0.69      1.00      0.82         9
#           59       0.70      0.88      0.78         8
#           60       0.75      0.90      0.82        10
#           61       1.00      0.78      0.88         9
#           62       0.85      1.00      0.92        11
#           63       0.75      0.60      0.67        10
#           64       0.62      0.89      0.73         9
#           65       0.86      0.86      0.86         7
#           66       1.00      0.62      0.77         8
#           67       0.88      0.70      0.78        10
#           68       0.90      0.90      0.90        10
#           69       0.88      0.78      0.82         9
#           70       0.56      0.90      0.69        10
#           71       0.67      0.33      0.44         6
#           72       0.82      0.90      0.86        10
#           73       0.69      0.90      0.78        10
#           74       0.90      0.82      0.86        11
#           75       0.55      0.75      0.63         8
#           76       0.58      1.00      0.74         7
#           77       0.80      0.80      0.80        10
#           78       1.00      0.90      0.95        10
#           79       0.88      0.88      0.88         8
#           80       0.75      0.38      0.50         8
#           81       1.00      0.67      0.80         9
#           82       0.88      0.64      0.74        11
#           83       0.90      1.00      0.95         9
#           84       0.75      0.75      0.75         8
#           85       0.89      0.80      0.84        10
#           86       0.73      0.73      0.73        11
#           87       0.86      0.75      0.80         8
#           88       0.69      0.90      0.78        10
#           89       0.89      0.73      0.80        11
#           90       0.73      0.80      0.76        10
#           91       0.86      0.67      0.75         9
#           92       0.75      0.90      0.82        10
#           93       0.89      1.00      0.94         8
#           94       0.78      0.88      0.82         8
#           95       1.00      1.00      1.00         9
#           96       0.89      0.80      0.84        10
#           97       0.88      1.00      0.93         7
#           98       0.89      1.00      0.94         8
#           99       0.78      1.00      0.88         7
#          100       0.89      0.80      0.84        10
#          101       0.50      0.62      0.56         8
#          102       0.71      0.62      0.67         8
#          103       0.89      1.00      0.94         8
#          104       1.00      0.78      0.88         9
#          105       0.75      1.00      0.86         9
#          106       1.00      0.89      0.94         9
#          107       0.78      0.88      0.82         8
#          108       0.67      0.75      0.71         8
#          109       1.00      0.80      0.89         5
#          110       0.82      0.90      0.86        10
#          111       0.90      0.90      0.90        10
#          112       0.80      0.89      0.84         9
#          113       0.57      0.44      0.50         9
#          114       0.88      0.88      0.88         8
#          115       1.00      0.80      0.89        10
#          116       0.89      0.80      0.84        10
#          117       0.91      1.00      0.95        10
#          118       0.80      0.50      0.62         8
#          119       0.88      0.78      0.82         9
#          120       1.00      0.92      0.96        12
#          121       1.00      0.90      0.95        10
#          122       0.90      0.90      0.90        10
#          123       0.62      0.62      0.62         8
#          124       0.75      0.90      0.82        10
#          125       0.89      0.80      0.84        10
#          126       0.75      0.33      0.46         9
#          127       0.91      0.91      0.91        11
#          128       0.78      0.88      0.82         8
#          129       0.73      1.00      0.85        11
#          130       1.00      0.78      0.88         9
#          131       0.67      0.73      0.70        11
#          132       0.75      1.00      0.86         6
#          133       0.78      0.70      0.74        10
#          134       0.80      0.80      0.80        10
#          135       0.82      1.00      0.90         9
#          136       0.57      0.44      0.50         9
#          137       0.56      0.91      0.69        11
#          138       1.00      0.73      0.84        11
#          139       1.00      0.90      0.95        10
#          140       0.73      0.80      0.76        10
#          141       0.67      0.92      0.77        13
#          142       0.80      0.80      0.80        10
#          143       0.50      0.56      0.53         9
#          144       0.67      0.44      0.53         9
#          145       0.70      0.64      0.67        11
#          146       0.78      0.88      0.82         8
#          147       0.83      1.00      0.91         5
#          148       0.86      0.67      0.75         9
#
#     accuracy                           0.81      1355
#    macro avg       0.82      0.81      0.80      1355
# weighted avg       0.82      0.81      0.81      1355

# %%
model.save("./models/pokemon_classifier.h5")
